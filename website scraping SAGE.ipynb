# %%
import urllib.request, urllib.error, urllib.parse
import requests
import csv
from urllib.request import build_opener, HTTPCookieProcessor, Request

#PUT JOURNAL URL HERE
url = 'https://journals.sagepub.com/loi/jmxa'


opener = build_opener(HTTPCookieProcessor())
request = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
response = opener.open(request, timeout=30)
allContent = str(response.read())

# %%
def toSheetHeader(name):
    # field names  
    fields = ['Title', 'Abstract','Journal']  
    
    # name of csv file  
    filename = name + " SCRAPED.csv"
    
    # writing to csv file  
    with open(filename, 'w') as csvfile:  
        # creating a csv writer object  
        csvwriter = csv.writer(csvfile)  
        
        # writing the fields  
        csvwriter.writerow(fields)

# %%
def toSheet(rows,name):
    # name of csv file  
    filename = name + " SCRAPED.csv"
    
    # writing to csv file  
    with open(filename, 'a') as csvfile:  
        # creating a csv writer object  
        csvwriter = csv.writer(csvfile)  
        
        # writing the data rows  
        csvwriter.writerows(rows)

# %%
allarticles = []


#GETTING JOURNAL TITLE

journal_index = allContent.find('<title')
journal_index = allContent.find('>',journal_index) + 1
journal = ""
while(allContent[journal_index]!="-"):
    journal = journal + allContent[journal_index]
    journal_index = journal_index+1


journal = journal.replace("\\n"," ")
toSheetHeader(journal)
                    
#FINDING THE LINK TO THE ISSUE, allContent is all of the code for the original URL                    
issue_index = 0
while(allContent.find('issue-link',issue_index,len(allContent))!=-1 and 
      allContent.find('2015',allContent.find('issue-link',issue_index,len(allContent)),len(allContent))!=-1):
    
    issue_index = allContent.find('issue-link',issue_index,len(allContent))
      
      
    issue_link_index = allContent.find("href=",issue_index,len(allContent))
    issue_link = ""
    i = issue_link_index+6 
                                  
    while(allContent[i]!='"'):
        issue_link = issue_link+allContent[i]
        i = i+1
    
    #getting code for ISSUE LINK here
    opener = build_opener(HTTPCookieProcessor())
    request = Request("https://journals.sagepub.com"+issue_link, headers={'User-Agent': 'Mozilla/5.0'})
    response = opener.open(request, timeout=30)
    webContent = str(response.read())

    
    #finding article title and the article link
    article_index = 0  
    ind = 0
    while(webContent.find('art_title linkable',article_index,len(webContent))!=-1):
        currarticle = []
        article_index = webContent.find('art_title linkable',article_index,len(webContent))
    
        link_index = webContent.find("href=",article_index,len(webContent))
        link = ""
        i = link_index+6
        while(webContent[i]!='"'):
            link = link+webContent[i]
            i = i+1

        title = ""
      
        i = webContent.find("hlFld-Title",i,len(webContent))
        i = webContent.find(">",i,len(webContent))
        i = i + 1
        while(webContent[i]!='<'):
            title = title+webContent[i]
            i = i+1

        title = title.replace("\\n","")
        currarticle.append(title)
        #print("\033[1m",title,"\033[0;0m")

        

        
        
        
      
        #OPENING LINK TO ARTICLE
        opener = build_opener(HTTPCookieProcessor())
        request = Request("https://journals.sagepub.com"+link, headers={'User-Agent': 'Mozilla/5.0'})
        response = opener.open(request, timeout=30)
        articleContent = str(response.read())
        
        print("https://journals.sagepub.com"+link)
        
        execute = True
        abstract_index = articleContent.find('abstractInFull',article_index,len(webContent))
        if (abstract_index == -1):
            abstract_index = articleContent.find('<div class="abstract">')
        if (abstract_index == -1):
            abstract_index = articleContent.find('<div class="section1')
        if (abstract_index == -1):
            execute = False
        print(abstract_index)
            
        if(execute):    
            abstract_index = articleContent.find("<p",abstract_index,len(articleContent))
            abstract_index = articleContent.find(">",abstract_index,len(articleContent))
            i = abstract_index+1
      
            end_abstract_index = articleContent.find("</p>",abstract_index,len(articleContent))

            abstract = ""

            while(i!=end_abstract_index):
                abstract = abstract+articleContent[i]
                i = i + 1
    
            abstract = abstract.replace("\\n"," ")
            currarticle.append(abstract)

        currarticle.append(journal)
        allarticles.append(currarticle)
        toSheet(allarticles,journal)
        allarticles=[]
        article_index = article_index+1
        issue_index = issue_index+1
# Out:
# https://journals.sagepub.com/doi/full/10.1177/0022242920965193
# -1
# https://journals.sagepub.com/doi/full/10.1177/0022242920942563
# 145919
# https://journals.sagepub.com/doi/full/10.1177/0022242920925038
# 140565
# https://journals.sagepub.com/doi/full/10.1177/0022242920929288
# 145527
# https://journals.sagepub.com/doi/full/10.1177/0022242920931451
# 142942
# https://journals.sagepub.com/doi/full/10.1177/0022242920943104
# 141712
# https://journals.sagepub.com/doi/full/10.1177/0022242920920295
# 142290
# https://journals.sagepub.com/doi/full/10.1177/0022242920929718
# 142477
# https://journals.sagepub.com/doi/full/10.1177/0022242918813577
# 141285
# https://journals.sagepub.com/doi/full/10.1177/0022242920936653
# -1
# https://journals.sagepub.com/doi/full/10.1177/0022242920937000
# 144480
# https://journals.sagepub.com/doi/full/10.1177/0022242920936205
# 141527
# https://journals.sagepub.com/doi/full/10.1177/0022242920917982
# 141149
# https://journals.sagepub.com/doi/full/10.1177/0022242920934495
# 144315
# https://journals.sagepub.com/doi/full/10.1177/0022242920929029
# 146279
# https://journals.sagepub.com/doi/full/10.1177/0022242920925054
# 143015
# https://journals.sagepub.com/doi/full/10.1177/0022242920916733
# 144765
# https://journals.sagepub.com/doi/full/10.1177/0022242920920859
# 143425
# https://journals.sagepub.com/doi/full/10.1177/0022242920925517
# 142307
# https://journals.sagepub.com/doi/full/10.1177/0022242920923307
# 142790
# https://journals.sagepub.com/doi/full/10.1177/0022242920920262
# 147449
# https://journals.sagepub.com/doi/full/10.1177/0022242920914861
# 143517
# https://journals.sagepub.com/doi/full/10.1177/0022242920924389
# 143382
# https://journals.sagepub.com/doi/full/10.1177/0022242919899393
# 140340
# https://journals.sagepub.com/doi/full/10.1177/0022242920911628
# 146208
# https://journals.sagepub.com/doi/full/10.1177/0022242920910096
# 143826
# https://journals.sagepub.com/doi/full/10.1177/0022242920913025
# 150127
# https://journals.sagepub.com/doi/full/10.1177/0022242920912732
# 140472
# https://journals.sagepub.com/doi/full/10.1177/0022242920911907
# 143770
# https://journals.sagepub.com/doi/full/10.1177/0022242920912272
# 140422
# https://journals.sagepub.com/doi/full/10.1177/0022242920912704
